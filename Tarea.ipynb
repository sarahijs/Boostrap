# {'alto': [3, 6]}
# {'valores': [1, 2, 1, 1, 1, 2, 2, 3, 4], 'bins': 3}
# ...

# %%
with open("datos tarea 1.jason","w")as f:
  json.dump(diccionario,f)

# %%
with open("datos tarea 1.jason")as f:
    diccionario=json.load(f)
print(diccionario)
# Out:
# {'simple': {'A': [-2.488575443458036, -0.7822376969509465, 0.28845111258242856, -0.24929866249570837, -2.282828453909866], 'B': [0.6213308024515721, 0.3581042948004616, -0.32661096342538704, -0.5637266019055921, 0.2515484395020845]}, 'competencia': {'alto': [3, 6]}, 'histograma': {'valores': [1, 2, 1, 1, 1, 2, 2, 3, 4], 'bins': 3}, 'egresos': {'valores': [0.07345949818363877, -0.33875968320360006, -1.8837514937781192, 3.329603393759705, 0.28446528824329576, -0.372093192941912, -0.03446333983564582, -0.001918799540025172, -0.9624216791817515, -0.0038555122509932177, 0.774890764888576, 0.8520611787663127, 21.987186266533705, 0.8266180253237922, -1.296866730857221, 0.034929033077357154, -0.14811730859940986, 0.01547655592201942, -0.32176623443737207, 3.311461631323349, 0.0034955455361506387, 0.04814788627063635, 1.1769661107516172, -1.918525040648286, 0.03576243576704026, 0.5639404070892577, -0.056099946942245175, -12.873837226774235, -0.00030546416353655927, 6.269971299512026, -2.22040
# ...

# %%
from matplotlib import axes, patches, transforms
fig,axes=plt.subplot_mosaic([
    ['d','b','c'],
    ['a','a','a']

])


fig.set_size_inches(14,5)

A= [-2.488575443458036, -0.7822376969509465, 0.28845111258242856, -0.24929866249570837, -2.282828453909866]
B= [0.6213308024515721, 0.3581042948004616, -0.32661096342538704, -0.5637266019055921, 0.2515484395020845]

axes['d'].plot(A, marker='o', linestyle='-', color='red', label='A')
axes['d'].plot(B, marker='d', linestyle='--', color='pink', label='B')
axes['d'].set_title('Simple')
axes['d'].legend(loc='upper right')
axes['d'].grid(color='purple')
axes['d'].annotate("A",(2,0))
axes['d'].annotate("B",(2.5,-0.7))

axes['c'].set_title('Histograma')
valores = ([1, 2, 1, 1, 1, 2, 2, 3, 4])
bins=3
axes['c'].hist(valores)
axes['c'].hist(valores, bins, color="#00BFBF", ec="red")

axes['a'].set_ylabel('Eje Y')
axes['a'].set_xlabel('Eje X')
axes['a'].set_title('Egresos')


valores1= [0.07345949818363877, -0.33875968320360006, -1.8837514937781192, 3.329603393759705,
0.28446528824329576, -0.372093192941912, -0.03446333983564582, -0.001918799540025172, -0.9624216791817515,
-0.0038555122509932177, 0.774890764888576, 0.8520611787663127, 21.987186266533705, 0.8266180253237922,
-1.296866730857221, 0.034929033077357154, -0.14811730859940986, 0.01547655592201942, -0.32176623443737207,
3.311461631323349, 0.0034955455361506387, 0.04814788627063635, 1.1769661107516172, -1.918525040648286,
0.03576243576704026, 0.5639404070892577, -0.056099946942245175, -12.873837226774235, -0.00030546416353655927,
6.269971299512026, -2.220405309097172, -8.526499308039648, 0.02723483973384829, -0.0007951684850954861,
-0.1505890399535441, -0.00552105771017715, -2.096522293545686, 0.002944963949675879, 0.01615095804232496,
0.23485763610281588, -0.08488447937439521, 0.008595635678489132, 0.032345520138739245, 2.1278540498936858,
-9.370284453678332, 0.0006859217579703742, -9.937830343369153, 0.6605836887563626, -0.11307566459481175,
-0.00042242216524049646, 1.0555033125746025, -0.0008589970257658258, 0.0007227952937545818, 10.610915064777734,
-0.00039196753635825497, -1.7706146467830468, 0.00353570685064593, -0.0005949440502158922, -3.1249354267188596,
0.9854376237233721, 1.50559208635694e-06, -1.0830535741879506, -3.7232165323845203, -6.307283051322433,
0.0018411977179349898, -0.24146758066322127, -0.5466839200420032, -0.40104916314244504, 1.8469049014600947,
0.04181980541744403, 0.0906426916816267, -0.703258502528281, -4.80228045289002, -0.6407731815039721,
0.17753104309052667, -0.01633963655640491, -0.08179348815222753, 0.5193546533220442, 0.6292813290742986,
-0.08929133302989488, 0.08872690235525668, -2.742418608638422, 0.1160685161250872, 11.574023995393107,
0.13248616162473226, -0.21679647696902793, 8.949109922029066, 0.01147138580953001, 0.08378880675914246,
0.07223087028814834, 0.03402152021932916, 9.993626902908417, -2.130496357520066, 0.7581060834924223,
0.0005033388727870669, 1.0439833970401726, 2.2182796096233215, 1.515990627920067, 0.17970566891424167, 1.9617001097747782]

maximo=np.max(valores1)
minimo=np.min(valores1)
argmax=np.argmax(valores1)
argmin=np.argmin(valores1)


axes['a'].annotate("maximo",(argmax,maximo),xytext=(5,5),arrowprops={"facecolor":"purple"})
axes['a'].annotate("minimo",(argmin,minimo),xytext=(10,-4),arrowprops={"facecolor":"pink"})
axes['a'].axvline(x=82, color='purple')
axes['a'].axvline(x=92, color ='purple')
axes['a'].axhline(20, xmax=.5, color='purple')

axes['b'].set_title('Competencia')
x = ["a" , "b", "c"]
y = [0,3,6]
axes['b'].bar(x,y,color=['#00BFBF','#BF00BF','#BFBF00'])

axes['b'].legend(["b&c"])

axes['a'].annotate("Region de peligro", xy=(80,10),xytext=(66.8,8),arrowprops={"facecolor":"black"})
t1 = transforms.blended_transform_factory(axes['a'].transData, axes['a'].transAxes)
t2 = patches.Rectangle((0,0), width=4, height=4, transform=t1, color='#FF1493', alpha=1)
axes['a'].add_patch(t2)
leyenda=patches.Patch(color='#FF1493', label='R')
axes['a'].legend(handles=[leyenda])
axes['a'].plot(valores1)



plt.show()
